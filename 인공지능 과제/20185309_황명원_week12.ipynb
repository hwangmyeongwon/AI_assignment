# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)


cnn=Sequential()
cnn.add(Conv2D(6,(5,5),padding='same',activation='relu',input_shape=(28,28,1)))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(16,(5,5),padding='same',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(120,(5,5),padding='same',activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(84,activation='relu'))
cnn.add(Dense(10,activation='softmax'))


cnn.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=12,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()
# Out:
# Epoch 1/12
# 469/469 - 3s - loss: 0.2109 - accuracy: 0.9373 - val_loss: 0.0544 - val_accuracy: 0.9816 - 3s/epoch - 6ms/step
# Epoch 2/12
# 469/469 - 2s - loss: 0.0589 - accuracy: 0.9820 - val_loss: 0.0341 - val_accuracy: 0.9898 - 2s/epoch - 4ms/step
# Epoch 3/12
# 469/469 - 2s - loss: 0.0387 - accuracy: 0.9879 - val_loss: 0.0384 - val_accuracy: 0.9857 - 2s/epoch - 4ms/step
# Epoch 4/12
# 469/469 - 2s - loss: 0.0304 - accuracy: 0.9903 - val_loss: 0.0278 - val_accuracy: 0.9909 - 2s/epoch - 4ms/step
# Epoch 5/12
# 469/469 - 2s - loss: 0.0237 - accuracy: 0.9926 - val_loss: 0.0280 - val_accuracy: 0.9911 - 2s/epoch - 4ms/step
# Epoch 6/12
# 469/469 - 2s - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0295 - val_accuracy: 0.9903 - 2s/epoch - 4ms/step
# Epoch 7/12
# 469/469 - 2s - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.0270 - val_accuracy: 0.9914 - 2s/epoch - 4ms/step
# Epoch 8/12
# 469/469 - 2s - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0306 - val_accuracy: 0.9898 - 2s/epoch - 4ms/step
# Epoch 9/12
# 469/469 - 2s - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0278 - val_accuracy: 0.9916 - 2s/epoch - 4ms/step
# Epoch 10/12
# 469/469 - 2s - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0293 - val_accuracy: 0.9912 - 2s/epoch - 4ms/step
# Epoch 11/12
# 469/469 - 2s - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0380 - val_accuracy: 0.9904 - 2s/epoch - 4ms/step
# Epoch 12/12
# 469/469 - 2s - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0345 - val_accuracy: 0.9913 - 2s/epoch - 4ms/step
# 정확률은 99.12999868392944

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(128,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10,activation='softmax'))

cnn.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=12,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()
# Out:
# Epoch 1/12
# 469/469 - 7s - loss: 0.2379 - accuracy: 0.9283 - val_loss: 0.0508 - val_accuracy: 0.9827 - 7s/epoch - 14ms/step
# Epoch 2/12
# 469/469 - 4s - loss: 0.0830 - accuracy: 0.9750 - val_loss: 0.0396 - val_accuracy: 0.9863 - 4s/epoch - 8ms/step
# Epoch 3/12
# 469/469 - 4s - loss: 0.0620 - accuracy: 0.9808 - val_loss: 0.0304 - val_accuracy: 0.9899 - 4s/epoch - 8ms/step
# Epoch 4/12
# 469/469 - 4s - loss: 0.0510 - accuracy: 0.9847 - val_loss: 0.0307 - val_accuracy: 0.9901 - 4s/epoch - 8ms/step
# Epoch 5/12
# 469/469 - 4s - loss: 0.0447 - accuracy: 0.9859 - val_loss: 0.0311 - val_accuracy: 0.9898 - 4s/epoch - 8ms/step
# Epoch 6/12
# 469/469 - 4s - loss: 0.0388 - accuracy: 0.9868 - val_loss: 0.0277 - val_accuracy: 0.9903 - 4s/epoch - 8ms/step
# Epoch 7/12
# 469/469 - 4s - loss: 0.0347 - accuracy: 0.9890 - val_loss: 0.0310 - val_accuracy: 0.9907 - 4s/epoch - 8ms/step
# Epoch 8/12
# 469/469 - 4s - loss: 0.0330 - accuracy: 0.9894 - val_loss: 0.0266 - val_accuracy: 0.9918 - 4s/epoch - 8ms/step
# Epoch 9/12
# 469/469 - 4s - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.0316 - val_accuracy: 0.9909 - 4s/epoch - 8ms/step
# Epoch 10/12
# 469/469 - 4s - loss: 0.0247 - accuracy: 0.9916 - val_loss: 0.0293 - val_accuracy: 0.9914 - 4s/epoch - 8ms/step
# Epoch 11/12
# 469/469 - 4s - loss: 0.0247 - accuracy: 0.9915 - val_loss: 0.0286 - val_accuracy: 0.9918 - 4s/epoch - 8ms/step
# Epoch 12/12
# 469/469 - 4s - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.0297 - val_accuracy: 0.9914 - 4s/epoch - 8ms/step
# 정확률은 99.14000034332275

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(128,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10,activation='softmax'))

cnn.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=12,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()
# Out:
# Epoch 1/12
# 469/469 - 4s - loss: 0.5179 - accuracy: 0.8172 - val_loss: 0.3510 - val_accuracy: 0.8726 - 4s/epoch - 9ms/step
# Epoch 2/12
# 469/469 - 4s - loss: 0.3419 - accuracy: 0.8791 - val_loss: 0.2847 - val_accuracy: 0.8990 - 4s/epoch - 8ms/step
# Epoch 3/12
# 469/469 - 4s - loss: 0.2902 - accuracy: 0.8949 - val_loss: 0.2604 - val_accuracy: 0.9040 - 4s/epoch - 8ms/step
# Epoch 4/12
# 469/469 - 4s - loss: 0.2563 - accuracy: 0.9066 - val_loss: 0.2369 - val_accuracy: 0.9119 - 4s/epoch - 8ms/step
# Epoch 5/12
# 469/469 - 4s - loss: 0.2358 - accuracy: 0.9137 - val_loss: 0.2318 - val_accuracy: 0.9134 - 4s/epoch - 8ms/step
# Epoch 6/12
# 469/469 - 4s - loss: 0.2138 - accuracy: 0.9210 - val_loss: 0.2336 - val_accuracy: 0.9145 - 4s/epoch - 8ms/step
# Epoch 7/12
# 469/469 - 4s - loss: 0.1977 - accuracy: 0.9264 - val_loss: 0.2198 - val_accuracy: 0.9200 - 4s/epoch - 8ms/step
# Epoch 8/12
# 469/469 - 4s - loss: 0.1799 - accuracy: 0.9334 - val_loss: 0.2137 - val_accuracy: 0.9255 - 4s/epoch - 8ms/step
# Epoch 9/12
# 469/469 - 4s - loss: 0.1661 - accuracy: 0.9386 - val_loss: 0.2179 - val_accuracy: 0.9242 - 4s/epoch - 8ms/step
# Epoch 10/12
# 469/469 - 4s - loss: 0.1551 - accuracy: 0.9414 - val_loss: 0.2143 - val_accuracy: 0.9256 - 4s/epoch - 8ms/step
# Epoch 11/12
# 469/469 - 4s - loss: 0.1484 - accuracy: 0.9441 - val_loss: 0.2235 - val_accuracy: 0.9275 - 4s/epoch - 8ms/step
# Epoch 12/12
# 469/469 - 4s - loss: 0.1364 - accuracy: 0.9481 - val_loss: 0.2205 - val_accuracy: 0.9277 - 4s/epoch - 8ms/step
# 정확률은 92.76999831199646

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam

(x_train,y_train),(x_test,y_test)=cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
cnn.add(Conv2D(32,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(512,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10,activation='softmax'))

cnn.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='best')
plt.grid()
plt.show()

cnn.save("my_cnn.h5")
# Out:
# Epoch 1/30
# 391/391 - 5s - loss: 1.6553 - accuracy: 0.3906 - val_loss: 1.3151 - val_accuracy: 0.5259 - 5s/epoch - 12ms/step
# Epoch 2/30
# 391/391 - 4s - loss: 1.2867 - accuracy: 0.5400 - val_loss: 1.1391 - val_accuracy: 0.5942 - 4s/epoch - 10ms/step
# Epoch 3/30
# 391/391 - 4s - loss: 1.1273 - accuracy: 0.6037 - val_loss: 0.9769 - val_accuracy: 0.6516 - 4s/epoch - 10ms/step
# Epoch 4/30
# 391/391 - 4s - loss: 1.0051 - accuracy: 0.6452 - val_loss: 0.9118 - val_accuracy: 0.6763 - 4s/epoch - 10ms/step
# Epoch 5/30
# 391/391 - 4s - loss: 0.9125 - accuracy: 0.6780 - val_loss: 0.8369 - val_accuracy: 0.7068 - 4s/epoch - 9ms/step
# Epoch 6/30
# 391/391 - 4s - loss: 0.8411 - accuracy: 0.7049 - val_loss: 0.7807 - val_accuracy: 0.7236 - 4s/epoch - 9ms/step
# Epoch 7/30
# 391/391 - 4s - loss: 0.7867 - accuracy: 0.7223 - val_loss: 0.7348 - val_accuracy: 0.7466 - 4s/epoch - 10ms/step
# Epoch 8/30
# 391/391 - 4s - loss: 0.7432 - accuracy: 0.7380 - val_loss: 0.7162 - val_accuracy: 0.7475 - 4s/epoch - 10ms/step
# Epoch 9/30
# 391/391 - 4s - loss: 0.7193 - accuracy: 0.7474 - val_loss: 0.7184 - val_accuracy: 0.7497 - 4s/epoch - 10ms/step
# Epoch 10/30
# 391/391 - 4s - loss: 0.6798 - accuracy: 0.7609 - val_loss: 0.6727 - val_accuracy: 0.7662 - 4s/epoch - 9ms/step
# Epoch 11/30
# 391/391 - 4s - loss: 0.6564 - accuracy: 0.7689 - val_loss: 0.6794 - val_accuracy: 0.7681 - 4s/epoch - 9ms/step
# Epoch 12/30
# 391/391 - 4s - loss: 0.6265 - accuracy: 0.7798 - val_loss: 0.6466 - val_accuracy: 0.7772 - 4s/epoch - 9ms/step
# Epoch 13/30
# 391/391 - 4s - loss: 0.6061 - accuracy: 0.7847 - val_loss: 0.6546 - val_accuracy: 0.7723 - 4s/epoch - 9ms/step
# Epoch 14/30
# 391/391 - 4s - loss: 0.5852 - accuracy: 0.7933 - val_loss: 0.6447 - val_accuracy: 0.7785 - 4s/epoch - 9ms/step
# Epoch 15/30
# 391/391 - 4s - loss: 0.5687 - accuracy: 0.7975 - val_loss: 0.6631 - val_accuracy: 0.7704 - 4s/epoch - 10ms/step
# Epoch 16/30
# 391/391 - 4s - loss: 0.5486 - accuracy: 0.8059 - val_loss: 0.6152 - val_accuracy: 0.7886 - 4s/epoch - 9ms/step
# Epoch 17/30
# 391/391 - 4s - loss: 0.5324 - accuracy: 0.8108 - val_loss: 0.6130 - val_accuracy: 0.7916 - 4s/epoch - 9ms/step
# Epoch 18/30
# 391/391 - 4s - loss: 0.5183 - accuracy: 0.8144 - val_loss: 0.6287 - val_accuracy: 0.7888 - 4s/epoch - 9ms/step
# Epoch 19/30
# 391/391 - 4s - loss: 0.5036 - accuracy: 0.8217 - val_loss: 0.6342 - val_accuracy: 0.7865 - 4s/epoch - 10ms/step
# Epoch 20/30
# 391/391 - 4s - loss: 0.4947 - accuracy: 0.8231 - val_loss: 0.6254 - val_accuracy: 0.7917 - 4s/epoch - 10ms/step
# Epoch 21/30
# 391/391 - 4s - loss: 0.4796 - accuracy: 0.8304 - val_loss: 0.6090 - val_accuracy: 0.7952 - 4s/epoch - 10ms/step
# Epoch 22/30
# 391/391 - 4s - loss: 0.4693 - accuracy: 0.8329 - val_loss: 0.6177 - val_accuracy: 0.7940 - 4s/epoch - 10ms/step
# Epoch 23/30
# 391/391 - 4s - loss: 0.4650 - accuracy: 0.8341 - val_loss: 0.6106 - val_accuracy: 0.7936 - 4s/epoch - 9ms/step
# Epoch 24/30
# 391/391 - 4s - loss: 0.4503 - accuracy: 0.8396 - val_loss: 0.6189 - val_accuracy: 0.7933 - 4s/epoch - 9ms/step
# Epoch 25/30
# 391/391 - 4s - loss: 0.4384 - accuracy: 0.8433 - val_loss: 0.6181 - val_accuracy: 0.7945 - 4s/epoch - 10ms/step
# Epoch 26/30
# 391/391 - 4s - loss: 0.4441 - accuracy: 0.8413 - val_loss: 0.6137 - val_accuracy: 0.7938 - 4s/epoch - 9ms/step
# Epoch 27/30
# 391/391 - 4s - loss: 0.4219 - accuracy: 0.8500 - val_loss: 0.6182 - val_accuracy: 0.7965 - 4s/epoch - 10ms/step
# Epoch 28/30
# 391/391 - 4s - loss: 0.4167 - accuracy: 0.8488 - val_loss: 0.6045 - val_accuracy: 0.8000 - 4s/epoch - 9ms/step
# Epoch 29/30
# 391/391 - 4s - loss: 0.4111 - accuracy: 0.8533 - val_loss: 0.6444 - val_accuracy: 0.7871 - 4s/epoch - 9ms/step
# Epoch 30/30
# 391/391 - 4s - loss: 0.4005 - accuracy: 0.8573 - val_loss: 0.6144 - val_accuracy: 0.8003 - 4s/epoch - 9ms/step
# 정확률은 80.03000020980835

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

cnn=tf.keras.models.load_model("my_cnn.h5")
cnn.summary()

(x_train,y_train),(x_test,y_test)=cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

res=cnn.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 30, 30, 32)        896
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 64)        18496
#
#  conv2d_14 (Conv2D)          (None, 10, 10, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_8 (Dropout)         (None, 5, 5, 64)          0
#
#  flatten_4 (Flatten)         (None, 1600)              0
#
#  dense_8 (Dense)             (None, 512)               819712
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 890,410
# Trainable params: 890,410
# Non-trainable params: 0
# _________________________________________________________________
# 정확률은 80.03000020980835
